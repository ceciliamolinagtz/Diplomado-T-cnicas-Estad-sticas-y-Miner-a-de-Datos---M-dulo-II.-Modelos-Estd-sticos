# %% [markdown]
# <div style="border-left: 8px solid #004D40; border-right: 2px solid #E2E8F0; border-top: 2px solid #E2E8F0; border-bottom: 2px solid #E2E8F0; padding: 25px; border-radius: 4px; background-color: #F4F7F5; font-family: 'Segoe UI', Arial, sans-serif; box-shadow: 0 4px 6px -1px rgba(0, 0, 0, 0.05);">
#     <span style="color: #B8860B; font-weight: bold; letter-spacing: 1.5px; font-size: 0.9em; text-transform: uppercase;">FES Acatlán • UNAM</span>
#     <h1 style="color: #004D40; font-size: 2.2em; font-weight: 700; margin-top: 5px; margin-bottom: 5px; line-height: 1.2;">Diplomado en Técnicas Estadísticas y Minería de Datos</h1>
#     <h3 style="color: #2F4F4F; font-size: 1.3em; font-weight: 400; margin-top: 0; margin-bottom: 20px;">Módulo II: Modelos Estadísticos</h3>
#     <h3 style="color: #2F4F4F; font-size: 1.3em; font-weight: 400; margin-top: 0; margin-bottom: 20px;"> <strong>Notebook 2: Variables aleatorias </strong> </h3>
#     <hr style="border: 0; height: 1px; background: #CBD5E0; margin-bottom: 20px;">
#     <table style="width: 100%; border-collapse: collapse; font-size: 0.95em; color: #2F4F4F; background-color: transparent;">
#         <tr style="background-color: transparent;">
#             <td style="padding: 4px 0; width: 50%; background-color: transparent;"></td>
#             <td style="padding: 4px 0; width: 50%; text-align: right; font-size: calc(0.95em + 6pt); background-color: transparent;"><strong>Cecilia Molina Gutiérrez</strong></td>
#         </tr>
#         <tr style="background-color: transparent;">
#             <td style="padding: 4px 0; background-color: transparent;"><strong>Profesora:</strong> Act. Claudia C. Reyes Montes de Oca</td>
#             <td style="padding: 4px 0; text-align: right; background-color: transparent;"><strong>Fecha:</strong> 28 de Julio 2026</td>
#         </tr>
#     </table>
# </div>

# %%
import numpy as np # importamos Numpy
import numpy.random as npr # para generar numeros aleeatorios
import matplotlib.pyplot as plt # Para graficar
import scipy.stats as sps # distribuciones 
import plotly.graph_objects as go
from scipy.stats import bernoulli # importar cada distribución (añadir todas las distribuciones que vamos a usar)

import plotly.io as pio

pio.renderers.default = "notebook_connected"  # O prueba con "iframe"

# %pip install kaleido
# %pip install kaleido==0.1.0post1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## <font color='2F855A'>Tabla de contenidos<font><a class='anchor' id='top'></a>
# - [1. Variables aleatorias discretas](#1)
# - [1.1 Distribución Uniforme Discreta](#2)
# - [1.2 Distribución de Bernoulli](#3)
# - [1.3 Distribución Binomial](#4)
# - [1.4 Distribución Geométrica](#5)
# - [1.5 Distribución de Poisson](#6)
# - [1.6 Distribución Binomial negativa](#7)
# - [1.7 Distribución Hipergeométrica](#8)
# - [2. Variables aleatorias continuas](#9)
# - [2.1 Distribución Uniforme Continua](#10)
# - [2.2 Distribución Normal](#11)
# - [2.3 Distribución Exponencial](#12)
# - [2.4 Distribución Gamma](#13)
# - [3. Función generadora de momentos (FGM)](#14)
# - [4. Función característica (FC)](#15)
# - [5. Ley de los Grandes Números](#16)
# - [6. Teorema Central del Límite](#17)
# - [7. Conclusiones](#18)
# - [Referencias](#19)

# %% [markdown]
# ### <font color='2F855A'>¿Qué es una variable aleatoria?<font>
#
# Al hacer un experimento, el resultado directo puede ser algo no númerico, como 'sol' o 'águila' en el caso de lanzar una moneda. Una **variable aleatoria** es una regla o función que asigna un número real a cada resultado posible de ese experimento.
#
# Matemáticamente, se define como una transformación $X$ del espacio muestral $\Omega$ a $\mathbb{R}$, es decir, $X: \Omega \to \mathbb{R}$.
#
# Principalmente pueden dividirse en:
# - **Discretas:** toman un número finito o numerable de valores.
# - **Continuas:** Pueden tomar cualquier valor en un intervalo.

# %% [markdown]
# ## <a id="1"></a><font color="#2F855A">1. Variables aleatorias discretas</font>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Definición:</b> Se dice que una variable aleatoria $Y$ es <b>discreta</b> si puede tomar sólo un número finito o contablemente infinito de valores distintos.
#     <div style="text-align: right; margin-top: 10px; font-size: 0.9em; color: #1A365D;">
#         <i>(Wackerly, Mendenhall, Scheaff, xx, p. 87)</i>
#     </div>
# </div>

# %% [markdown]
# Como ciertos tipos de variables aleatorias se presentan frecuentemente en la práctica, es útil tener a la mano la probabilidad para cada valor de una variable aleatoria. Este conjunto de probabilidades se conoce como <b> distribución de probabilidad </b> de la variable aleatoria discreta.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Definición:</b> La probabilidad de que $Y$ tome el valor $y$, $P(Y=y)$, se define como la suma de las probabilidades de todos los puntos muestrales en S a los que se asigna el valor $y$. A veces denotaremos $P(Y=y)$ por $p(y)$.
#     <div style="text-align: right; margin-top: 10px; font-size: 0.9em; color: #1A365D;">
#         <i>(Wackerly, Mendenhall, Scheaff, xx, p. 88)</i>
#     </div>
# </div>

# %% [markdown]
# ### <a id="2"></a><font color="#004D40">1.1 Distribución Uniforme Discreta</font>

# %% [markdown]
# Cuando tenemos $n$ resultados diferentes y todos tienen la misma probabilidad de ocurrir se da la **distribución uniforme**.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Definición:</b> Decimos que una variable aleatoria $X$ tiene una distribución uniforme discreta sobre el conjunto de $n$ números ${x_1, \dots,x_n}$ si la probabilidad de que $X$ tome cualquiera de estos valores es constante $1/n$.
#     <div style="text-align: right; margin-top: 10px; font-size: 0.9em; color: #1A365D;">
#         <i>(Rincón, 2014, p. 212)</i>
#     </div>
# </div>

# %% [markdown]
# Esto quiere decir que podemos expresar la **función de probabilidad** como
# $$f_{X}(k)=\mathbb{P}(X=k)=\begin{cases}
# \frac{1}{n} &\quad \text{si } k\in\{x_{1},\dots,x_{n}\} \\
# 0 &\quad \text{en otro caso}
# \end{cases}$$

# %% [markdown]
# #### ESPERANZA Y VARIANZA DE LA DISTRIBUCIÓN UNIFORME DISCRETA
#
# Si se tiene una distribución uniforme discreta, en este caso, se tiene que la esperanza y varianza están dadas por:
# 	$$\mathbb{E}[X] = \sum_{k}kf_{X}(k)=\frac{x_n + x_1}{2}.$$
# 	y
# 	$$\text{Var}(X) = \mathbb{E}[(X-\mathbb{E}[X])^{2}] =\sum_{k}(k-\mathbb{E}[X])^{2}f_{X}(k)=\frac{(x_n - x_1+1)^2-1}{12}$$

# %% [markdown]
# <h3>&#128202; <font color="#004D40">Visualización en Python</font>  </3>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Configuración del estilo general de la gráfica para GitHub/Academic Notebooks
sns.set_theme(style="whitegrid", palette="muted")
plt.rcParams.update(
    {
        "font.family": "sans-serif",
        "font.size": 10,
        "axes.labelsize": 11,
        "axes.titlesize": 13,
        "xtick.labelsize": 9,
        "ytick.labelsize": 9,
        "figure.dpi": 150,  # Alta resolución para renderizado fluido en GitHub
    }
)

# 1. Definición de parámetros del espacio muestral
min_val = 0
max_val = 20
x = np.arange(min_val, max_val)
n_obs = len(x)

# 2. Función de Masa de Probabilidad (PMF)
pmf_unif = np.full_like(x, 1 / n_obs, dtype=float)

# 3. Creación de la figura
fig, ax = plt.subplots(figsize=(8, 4.5))

# Paleta de color estilo institucional / UNAM (Azul Marino Profundo)
primary_color = "#0F4C81"
edge_color = "#082947"

# Graficado de la función de masa
bars = ax.bar(
    x,
    pmf_unif,
    width=0.6,
    color=primary_color,
    edgecolor=edge_color,
    linewidth=1.2,
    alpha=0.85,
    label=f"PMF: $P(X=x) = 1/{n_obs} = {1/n_obs:.2f}$",
)

# Línea discontinua que resalta la equiprobabilidad
ax.axhline(
    y=1 / n_obs,
    color="#E63946",
    linestyle="--",
    linewidth=1.5,
    alpha=0.7,
    label="Probabilidad constante",
)

# Personalización de ejes y cuadrícula
ax.set_xticks(x)
ax.set_ylim(0, (1 / n_obs) * 1.35)  # Espacio superior para respiración gráfica
ax.set_xlabel("Valores de la variable aleatoria ($x$)", fontweight="bold")
ax.set_ylabel("Probabilidad $P(X = x)$", fontweight="bold")

# Título y Subtítulo
ax.set_title(
    "Función de Masa de Probabilidad (PMF) - Distribución Uniforme Discreta",
    pad=15,
    fontweight="bold",
)

# Formato numérico en el eje Y a porcentaje/decimal limpio
ax.yaxis.set_major_formatter("{x:.2f}")

# Estilizado de la cuadrícula y bordes
ax.grid(True, linestyle=":", alpha=0.6)
sns.despine(top=True, right=True)

# Etiqueta de valor sobre cada barra para mayor claridad visual
for bar in bars:
    height = bar.get_height()
    ax.annotate(
        f"{height:.2f}",
        xy=(bar.get_x() + bar.get_width() / 2, height),
        xytext=(0, 3),  # Desplazamiento vertical de 3pt
        textcoords="offset points",
        ha="center",
        va="bottom",
        fontsize=7.5,
        color="#333333",
    )

# Leyenda dentro del gráfico
ax.legend(loc="upper right", frameon=True, facecolor="white", framealpha=0.9)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>&#128187; <font color="#004D40"> Simulación en Python</font>  </3>

# %%
import numpy as np
import plotly.graph_objects as go

# 1. Semilla para reproducibilidad
np.random.seed(123)

# 2. Parámetros de la distribución Uniforme Discreta (Ejemplo: Dado justo de 6 caras)
a_param = 1
b_param = 6
N_outcomes = b_param - a_param + 1  # Número de resultados posibles (6)
n_simulations = 10000

# 3. Generación de números uniformes estándar U ~ Unif(0, 1)
U = np.random.random(n_simulations)

# 4. Aplicación de la Transformación Inversa: X = a + floor(N * U)
uniformes_discretas_sim = a_param + np.floor(N_outcomes * U).astype(int)

# 5. Frecuencias relativas observadas en la simulación
unique_vals, counts = np.unique(uniformes_discretas_sim, return_counts=True)
freq_relativas = counts / n_simulations

# 6. Masa de probabilidad teórica PMF: P(X = k) = 1 / N
k_vals = np.arange(a_param, b_param + 1)
pmf_vals = np.full(shape=len(k_vals), fill_value=1.0 / N_outcomes)

# 7. Construcción de la figura interactiva con Plotly
fig = go.Figure()

# Barras de la Simulación Monte Carlo
fig.add_trace(
    go.Bar(
        x=unique_vals,
        y=freq_relativas,
        name="Simulación Monte Carlo",
        marker=dict(
            color="rgba(15, 76, 129, 0.70)",  # Azul Marino UNAM con transparencia
            line=dict(color="#082947", width=1),
        ),
    )
)

# Puntos/Líneas de la Masa Teórica PMF
fig.add_trace(
    go.Scatter(
        x=k_vals,
        y=pmf_vals,
        mode="markers+lines",
        name="Masa Teórica $P(X=k)$",
        marker=dict(color="#E63946", size=8),  # Rojo Cárdeno
        line=dict(color="#E63946", width=2, dash="dash"),
    )
)

# Personalización del diseño (Layout estilizado)
fig.update_layout(
    title=dict(
        text=f"<b>Simulación por Transformación Inversa: Uniforme Discreta UnifDiscreta({a_param}, {b_param})</b>",
        font=dict(size=16, family="sans-serif"),
        x=0.05,
    ),
    xaxis=dict(
        title="<b>Variable aleatoria discreta (k)</b>",
        tickmode="linear",
        tick0=a_param,
        dtick=1,
        showgrid=True,
        gridcolor="#E2E8F0",
        zeroline=False,
    ),
    yaxis=dict(
        title="<b>Probabilidad / Frecuencia Relativa</b>",
        showgrid=True,
        gridcolor="#E2E8F0",
        zeroline=False,
    ),
    plot_bgcolor="white",
    paper_bgcolor="white",
    bargap=0.25,
    legend=dict(
        x=0.98,
        y=0.98,
        xanchor="right",
        yanchor="top",
        bgcolor="rgba(255, 255, 255, 0.9)",
        bordercolor="#CBD5E1",
        borderwidth=1,
    ),
    width=850,
    height=480,
)

import plotly.io as pio
# Configura Plotly para exportar estático
pio.renderers.default = "png"
fig.show()

# %% [markdown]
# [Volver al inicio](#top)

# %% [markdown]
# ### <a id="3"></a><font color="#004D40">1.2 Distribución de Bernoulli</font>

# %% [markdown]
# Modela un experimento con solo dos resultados posibles: 'éxito' (1) y 'fracaso' (0).

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Definición:</b> Un <b> ensayo de Bernoulli</b> se define como aquel experimento aleatorio con únicamente dos posibles resultados, llamados genéricamente: éxito y fracaso. Supondremos que las probabilidades de estos resultados son $p$ y $1-p$, respectivamente. Si se define la variable aleatoria $X$ como aquella función que lleva el resultado éxito al número 1 y el resultado fracaso al número 0, entonces decimos que $X$ tiene una <b>distribución Bernoulli</b> con parámetro $p \in (0,1)$. La función de probabilidad se puede escribir de la siguiente forma.
#     $$f(x)= \begin{cases}
#     1-p & \text{si  } x=0 \\
#     p & \text{si  } x=1 \\
#     0 & \text{en otro caso}
#     \end{cases}$$
#     <div style="text-align: right; margin-top: 10px; font-size: 0.9em; color: #1A365D;">
#         <i>(Rincón, 2014, p. 217)</i>
#     </div>
# </div>

# %% [markdown]
# <h3>&#128202; <font color="#004D40">Visualización en Python</font>  </3>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import bernoulli

# Configuración del estilo general para el Notebook
sns.set_theme(style="whitegrid", palette="muted")
plt.rcParams.update(
    {
        "font.family": "sans-serif",
        "font.size": 10,
        "axes.labelsize": 11,
        "axes.titlesize": 13,
        "xtick.labelsize": 10,
        "ytick.labelsize": 9,
        "figure.dpi": 150,  # Calidad para previsualización en GitHub
    }
)

# 1. Definición de parámetros
p = 0.70  # Probabilidad de éxito
q = 1 - p  # Probabilidad de fracaso

x = np.array([0, 1])
pmf_bernoulli = bernoulli.pmf(x, p)

# 2. Creación de la figura
fig, ax = plt.subplots(figsize=(6.5, 4.5))

# Colores institucionales diferenciados para Fracaso (Rojo/Gris) y Éxito (Azul UNAM)
colors = ["#E53E3E", "#0F4C81"]
edge_colors = ["#9B2C2C", "#082947"]

# Graficado de las barras de probabilidad
bars = ax.bar(
    x,
    pmf_bernoulli,
    width=0.35,
    color=colors,
    edgecolor=edge_colors,
    linewidth=1.2,
    alpha=0.85,
)

# Personalización de etiquetas del eje X
ax.set_xticks(x)
ax.set_xticklabels(["0\n(Fracaso)", "1\n(Éxito)"], fontweight="bold")
ax.set_ylim(0, 1.0)  # Límite vertical ajustado a 1 para escala de probabilidad completa
ax.set_xlabel("Resultado del ensayo ($x$)", fontweight="bold")
ax.set_ylabel("Probabilidad $P(X = x)$", fontweight="bold")

# Título de la gráfica
ax.set_title(
    f"Función de Masa de Probabilidad (PMF) - Distribución Bernoulli ($p = {p}$)",
    pad=15,
    fontweight="bold",
)

# Formato del eje Y a decimal
ax.yaxis.set_major_formatter("{x:.2f}")

# Estilizado de cuadrícula y bordes
ax.grid(True, linestyle=":", alpha=0.6)
sns.despine(top=True, right=True)

# Anotaciones numéricas exactas sobre cada barra
for bar in bars:
    height = bar.get_height()
    ax.annotate(
        f"{height:.2f}\n({height*100:.0f}%)",
        xy=(bar.get_x() + bar.get_width() / 2, height),
        xytext=(0, 6),
        textcoords="offset points",
        ha="center",
        va="bottom",
        fontsize=9,
        fontweight="bold",
        color="#2D3748",
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# [Volver al inicio](#top)

# %% [markdown]
# ### <a id="4"></a><font color="#004D40">1.3 Distribución Binomial</font>

# %% [markdown]
# Para experimentos que consisten en la observación de experimentos idénticos e independientes, cada uno de los cuáles puede resultar en una de dos salidas.
#
# Por ejemplo:
# - Artículos saliendo de línea de producción: pueden ser '**defectuoso**' o '**no defectuoso**'.
# - Disparos en tiro al blanco: pueden ser '**acierto**' o '**no acierto**'.
# - Encuesta para ver quienes están a favor de un candidato: '**a favor**' o '**en contra**'.

# %% [markdown]
# <table style="width: 100%; border-collapse: collapse; font-family: sans-serif; margin: 20px 0; border-radius: 8px; overflow: hidden; box-shadow: 0 2px 6px rgba(0,0,0,0.08);">
#     <thead>
#         <tr style="background-color: #1B4D3E; color: #FFFFFF; text-align: center; font-size: 1.05em;">
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Función de probabilidad</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Esperanza $\mathbb{E}[X]$</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Varianza $\text{Var}(X)$</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Función Generadora de Momentos</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style="background-color: #F0F7F4; color: #112A21; text-align: center; font-size: 1.25em;">
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle p(y) = \binom{n}{y}p^y(1-p)^{n-y} \\[4pt] \text{con } \\y=0,1,\dots,n \quad (0 \le p \le 1)$
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle np$
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle np(1-p)$
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle [pe^t + (1-p)]^n$
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# #### PROPIEDADES DE UN EXPERIMENTO BINOMIAL
# 1. Consiste en un número fijo $n$ de pruebas idénticas.
# 2. Cada prueba resulta en uno de dos resultados: éxito S, o fracaso F.
# 3. La probabilidad de éxito en una sola prueba es igual a algún valor $p$ y es el mismo de una prueba a la otra. La probabilidad de fracaso es igual a $q=(1-p)$.
# 4. Las pruebas son independientes.
# 5. La variable aleatoria de interés es $Y$, el número de éxitos observados durante las $n$ pruebas.

# %% [markdown]
# <h3>&#128202; <font color="#004D40">Visualización en Python</font>  </3>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import binom

# Configuración del estilo general para el Notebook
sns.set_theme(style="whitegrid", palette="muted")
plt.rcParams.update(
    {
        "font.family": "sans-serif",
        "font.size": 10,
        "axes.labelsize": 11,
        "axes.titlesize": 13,
        "xtick.labelsize": 9,
        "ytick.labelsize": 9,
        "figure.dpi": 150,  # Alta calidad para previsualización en GitHub
    }
)

# 1. Definición de parámetros
n = 20# Número de ensayos de Bernoulli
p = 0.60  # Probabilidad de éxito
k = np.arange(0, n + 1)  # Posibles números de éxitos: {0, 1, ..., 10}

pmf_binom = binom.pmf(k, n, p)
esperanza = n * p

# 2. Creación de la figura
fig, ax = plt.subplots(figsize=(8, 4.5))

# Paleta de colores institucional UNAM
primary_color = "#0F4C81"
edge_color = "#082947"

# Graficado de las barras de probabilidad
# Se reemplazó \text por \mathrm en la leyenda para evitar el ParseFatalException
bars = ax.bar(
    k,
    pmf_binom,
    width=0.6,
    color=primary_color,
    edgecolor=edge_color,
    linewidth=1.2,
    alpha=0.85,
    label=f"$X \\sim \\mathrm{{Binom}}(n={n}, p={p})$",
)

# Línea discontinua que marca la Esperanza Matemática E[X]
ax.axvline(
    x=esperanza,
    color="#E63946",
    linestyle="--",
    linewidth=1.8,
    label=f"Esperanza $E[X] = n \\cdot p = {esperanza:.1f}$",
)

# Personalización de ejes
ax.set_xticks(k)
ax.set_ylim(0, max(pmf_binom) * 1.25)  # Margen superior para anotaciones
ax.set_xlabel("Número de éxitos ($k$)", fontweight="bold")
ax.set_ylabel("Probabilidad $P(X = k)$", fontweight="bold")

# Título de la gráfica
ax.set_title(
    f"Función de Masa de Probabilidad (PMF) - Distribución Binomial ($n={n}, p={p}$)",
    pad=15,
    fontweight="bold",
)

# Formato numérico en el eje Y
ax.yaxis.set_major_formatter("{x:.2f}")

# Estilizado de cuadrícula y bordes
ax.grid(True, linestyle=":", alpha=0.6)
sns.despine(top=True, right=True)

# Anotación numérica sobre cada barra
for bar in bars:
    height = bar.get_height()
    if height >= 0.001:  # Omitir valores insignificantes para no saturar
        ax.annotate(
            f"{height:.3f}",
            xy=(bar.get_x() + bar.get_width() / 2, height),
            xytext=(0, 4),
            textcoords="offset points",
            ha="center",
            va="bottom",
            fontsize=8,
            color="#2D3748",
        )

# Leyenda dentro del gráfico
ax.legend(loc="upper left", frameon=True, facecolor="white", framealpha=0.9)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>&#128187; <font color="#004D40"> Simulación en Python</font>  </3>

# %%
import numpy as np
import plotly.graph_objects as go
from scipy.stats import binom

# 1. Semilla para reproducibilidad
np.random.seed(123)

# 2. Parámetros de la distribución Binomial
n_trials = 10
p_prob = 0.4
n_simulations = 10000

# 3. Generación de números uniformes estándar U ~ Unif(0, 1)
U = np.random.random(n_simulations)

# 4. Aplicación de la Transformación Inversa mediante la función cuantílica (escalonada)
binomiales_simuladas = binom.ppf(U, n=n_trials, p=p_prob)

# 5. Masa de probabilidad teórica PMF
k_vals = np.arange(0, n_trials + 1)
pmf_vals = binom.pmf(k_vals, n=n_trials, p=p_prob)

# 6. Cálculo de frecuencias relativas simuladas
unique, counts = np.unique(binomiales_simuladas, return_counts=True)
freq_relativas = counts / n_simulations

# 7. Construcción de la figura interactiva con Plotly
fig = go.Figure()

# Barras de la Simulación Monte Carlo
fig.add_trace(
    go.Bar(
        x=unique,
        y=freq_relativas,
        name="Simulación Monte Carlo",
        marker=dict(
            color="rgba(15, 76, 129, 0.70)",  # Azul Marino UNAM con transparencia
            line=dict(color="#082947", width=1),
        ),
    )
)

# Puntos/Líneas de la Probabilidad Teórica PMF
fig.add_trace(
    go.Scatter(
        x=k_vals,
        y=pmf_vals,
        mode="markers+lines",
        name="Masa Teórica $P(X=k)$",
        marker=dict(color="#E63946", size=8),  # Rojo Cárdeno
        line=dict(color="#E63946", width=2, dash="dash"),
    )
)

# Personalización del diseño (Layout estilizado)
fig.update_layout(
    title=dict(
        text=f"<b>Simulación por Transformación Inversa: Binomial Binom(n={n_trials}, p={p_prob})</b>",
        font=dict(size=16, family="sans-serif"),
        x=0.05,
    ),
    xaxis=dict(
        title="<b>Variable aleatoria discreta (k éxitos)</b>",
        tickmode="linear",
        tick0=0,
        dtick=1,
        showgrid=True,
        gridcolor="#E2E8F0",
        zeroline=False,
    ),
    yaxis=dict(
        title="<b>Probabilidad / Frecuencia Relativa</b>",
        showgrid=True,
        gridcolor="#E2E8F0",
        zeroline=False,
    ),
    plot_bgcolor="white",
    paper_bgcolor="white",
    bargap=0.2,
    legend=dict(
        x=0.98,
        y=0.98,
        xanchor="right",
        yanchor="top",
        bgcolor="rgba(255, 255, 255, 0.9)",
        bordercolor="#CBD5E1",
        borderwidth=1,
    ),
    width=850,
    height=480,
)

import plotly.io as pio
# Configura Plotly para exportar estático
pio.renderers.default = "png"
fig.show()

# %% [markdown]
# #### EJEMPLO EXTRA

# %% [markdown]
# [Volver al inicio](#top)

# %% [markdown]
# ### <a id="5"></a><font color="#004D40">1.4 Distribución Geométrica</font>

# %% [markdown]
# <table style="width: 100%; border-collapse: collapse; font-family: sans-serif; margin: 20px 0; border-radius: 8px; overflow: hidden; box-shadow: 0 2px 6px rgba(0,0,0,0.08);">
#     <thead>
#         <tr style="background-color: #1B4D3E; color: #FFFFFF; text-align: center; font-size: 1.05em;">
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Función de probabilidad</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Esperanza $\mathbb{E}[X]$</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Varianza $\text{Var}(X)$</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Función Generadora de Momentos</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style="background-color: #F0F7F4; color: #112A21; text-align: center; font-size: 1.25em;">
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle p(y) = p(1-p)^{y-1} \\[4pt] \text{ con } y=1,2,3,\dots$
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle \frac{1}{p}$
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle \frac{1-p}{p^2}$
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle \frac{pe^t}{1-(1-p)e^t}$
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <h3>&#128202; <font color="#004D40">Visualización en Python</font>  </3>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import geom

# Configuración del estilo general
sns.set_theme(style="whitegrid", palette="muted")
plt.rcParams.update(
    {
        "font.family": "sans-serif",
        "font.size": 10,
        "axes.labelsize": 11,
        "axes.titlesize": 13,
        "xtick.labelsize": 9,
        "ytick.labelsize": 9,
        "figure.dpi": 150,
    }
)

# 1. Parámetros de la distribución
p = 0.30  # Probabilidad de éxito en cada ensayo
k = np.arange(1, 16)  # Evaluamos de 1 a 15 intentos

# 2. PMF y Estadísticos Teóricos
pmf_geom = geom.pmf(k, p)
esperanza = 1 / p
varianza = (1 - p) / (p**2)
desv_est = np.sqrt(varianza)

# 3. Creación de la figura
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Colores institucionales UNAM
primary_color = "#0F4C81"
edge_color = "#082947"

# Graficado de barras de probabilidad
bars = ax.bar(
    k,
    pmf_geom,
    width=0.6,
    color=primary_color,
    edgecolor=edge_color,
    linewidth=1.2,
    alpha=0.85,
    label=f"$X \\sim \\mathrm{{Geom}}(p={p})$",
)

# Línea de la Esperanza Matemática E[X]
ax.axvline(
    x=esperanza,
    color="#E63946",
    linestyle="--",
    linewidth=1.8,
    label=f"Esperanza $E[X] = 1/p = {esperanza:.2f}$",
)



# Personalización de ejes
ax.set_xticks(k)
ax.set_ylim(0, max(pmf_geom) * 1.25)
ax.set_xlabel("Número de ensayos hasta el primer éxito ($k$)", fontweight="bold")
ax.set_ylabel("Probabilidad $P(X = k)$", fontweight="bold")

# Título
ax.set_title(
    f"Función de Masa de Probabilidad (PMF) - Distribución Geométrica ($p={p}$)",
    pad=15,
    fontweight="bold",
)

ax.yaxis.set_major_formatter("{x:.2f}")
ax.grid(True, linestyle=":", alpha=0.6)
sns.despine(top=True, right=True)

# Anotación numérica sobre cada barra
for bar in bars:
    height = bar.get_height()
    if height >= 0.005:  # Filtro para omitir valores extremadamente pequeños
        ax.annotate(
            f"{height:.3f}",
            xy=(bar.get_x() + bar.get_width() / 2, height),
            xytext=(0, 4),
            textcoords="offset points",
            ha="center",
            va="bottom",
            fontsize=7.5,
            color="#333333",
        )

# Leyenda dentro del gráfico
ax.legend(loc="upper right", frameon=True, facecolor="white", framealpha=0.95)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>&#128187; <font color="#004D40"> Simulación en Python</font>  </3>

# %%
import numpy as np
import plotly.graph_objects as go
from scipy.stats import geom

# 1. Semilla para reproducibilidad
np.random.seed(123)

# 2. Parámetros de la distribución Geométrica
p_prob = 0.30  # Probabilidad de éxito en cada ensayo
n_simulations = 10000

# 3. Generación de números uniformes estándar U ~ Unif(0, 1)
U = np.random.random(n_simulations)

# 4. Aplicación de la Transformación Inversa Analítica: X = ceil( ln(1 - U) / ln(1 - p) )
geometricas_simuladas = np.ceil(np.log(1.0 - U) / np.log(1.0 - p_prob)).astype(
    int
)

# 5. Frecuencias relativas observadas en la simulación
unique_vals, counts = np.unique(geometricas_simuladas, return_counts=True)
freq_relativas = counts / n_simulations

# 6. Masa de probabilidad teórica PMF
max_k = np.max(unique_vals)
k_vals = np.arange(1, max_k + 1)
pmf_vals = geom.pmf(k_vals, p=p_prob)

# 7. Construcción de la figura interactiva con Plotly
fig = go.Figure()

# Barras de la Simulación Monte Carlo
fig.add_trace(
    go.Bar(
        x=unique_vals,
        y=freq_relativas,
        name="Simulación Monte Carlo",
        marker=dict(
            color="rgba(15, 76, 129, 0.70)",  # Azul Marino UNAM con transparencia
            line=dict(color="#082947", width=1),
        ),
    )
)

# Puntos/Líneas de la Masa Teórica PMF
fig.add_trace(
    go.Scatter(
        x=k_vals,
        y=pmf_vals,
        mode="markers+lines",
        name="Masa Teórica $P(X=k)$",
        marker=dict(color="#E63946", size=8),  # Rojo Cárdeno
        line=dict(color="#E63946", width=2, dash="dash"),
    )
)

# Personalización del diseño (Layout estilizado)
fig.update_layout(
    title=dict(
        text=f"<b>Simulación por Transformación Inversa: Geométrica Geom(p={p_prob:.2f})</b>",
        font=dict(size=16, family="sans-serif"),
        x=0.05,
    ),
    xaxis=dict(
        title="<b>Número de ensayos hasta el primer éxito (k)</b>",
        tickmode="linear",
        tick0=1,
        dtick=1,
        showgrid=True,
        gridcolor="#E2E8F0",
        zeroline=False,
    ),
    yaxis=dict(
        title="<b>Probabilidad / Frecuencia Relativa</b>",
        showgrid=True,
        gridcolor="#E2E8F0",
        zeroline=False,
    ),
    plot_bgcolor="white",
    paper_bgcolor="white",
    bargap=0.20,
    legend=dict(
        x=0.98,
        y=0.98,
        xanchor="right",
        yanchor="top",
        bgcolor="rgba(255, 255, 255, 0.9)",
        bordercolor="#CBD5E1",
        borderwidth=1,
    ),
    width=850,
    height=480,
)

import plotly.io as pio
# Configura Plotly para exportar estático
pio.renderers.default = "png"
fig.show()

# %% [markdown]
# ### <a id="6"></a><font color="#004D40">1.5 Distribución de Poisson</font>

# %% [markdown]
# <table style="width: 100%; border-collapse: collapse; font-family: sans-serif; margin: 20px 0; border-radius: 8px; overflow: hidden; box-shadow: 0 2px 6px rgba(0,0,0,0.08);">
#     <thead>
#         <tr style="background-color: #1B4D3E; color: #FFFFFF; text-align: center; font-size: 1.05em;">
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Función de probabilidad</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Esperanza $\mathbb{E}[X]$</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Varianza $\text{Var}(X)$</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Función Generadora de Momentos</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style="background-color: #F0F7F4; color: #112A21; text-align: center; font-size: 1.25em;">
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle p(y) = \frac{\lambda^y e^{-\lambda}}{y!} \\[4pt] \text{ con } y=0,1,\dots$
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle \lambda$
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle \lambda$
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle exp[\lambda(e^t - 1)]$
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <h3>&#128202; <font color="#004D40">Visualización en Python</font>  </3>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import poisson

# Configuración del estilo general
sns.set_theme(style="whitegrid", palette="muted")
plt.rcParams.update(
    {
        "font.family": "sans-serif",
        "font.size": 10,
        "axes.labelsize": 11,
        "axes.titlesize": 13,
        "xtick.labelsize": 9,
        "ytick.labelsize": 9,
        "figure.dpi": 150,
    }
)

# 1. Parámetros de la distribución
lam = 4.0  # Tasa promedio de ocurrencia (lambda)
k = np.arange(0, 20)  # Evaluamos de 0 a 14 eventos

# 2. PMF y Estadísticos Teóricos
pmf_poisson = poisson.pmf(k, mu=lam)
esperanza = lam
varianza = lam
desv_est = np.sqrt(varianza)

# 3. Creación de la figura
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# Colores institucionales UNAM
primary_color = "#0F4C81"
edge_color = "#082947"

# Graficado de barras de probabilidad
bars = ax.bar(
    k,
    pmf_poisson,
    width=0.6,
    color=primary_color,
    edgecolor=edge_color,
    linewidth=1.2,
    alpha=0.85,
    label=f"$X \\sim \\mathrm{{Poisson}}(\\lambda={lam:.1f})$",
)

# Línea para la Esperanza Matemática E[X]
ax.axvline(
    x=esperanza,
    color="#E63946",
    linestyle="--",
    linewidth=1.8,
    label=f"Esperanza $E[X] = \\lambda = {esperanza:.1f}$",
)


# Personalización de ejes
ax.set_xticks(k)
ax.set_ylim(0, max(pmf_poisson) * 1.25)
ax.set_xlabel("Número de ocurrencias del evento ($k$)", fontweight="bold")
ax.set_ylabel("Probabilidad $P(X = k)$", fontweight="bold")

# Título de la gráfica
ax.set_title(
    f"Función de Masa de Probabilidad (PMF) - Distribución Poisson ($\\lambda={lam:.1f}$)",
    pad=15,
    fontweight="bold",
)

ax.yaxis.set_major_formatter("{x:.2f}")
ax.grid(True, linestyle=":", alpha=0.6)
sns.despine(top=True, right=True)

# Anotación numérica sobre cada barra
for bar in bars:
    height = bar.get_height()
    if height >= 0.001:  # Omitir valores extremadamente pequeños
        ax.annotate(
            f"{height:.3f}",
            xy=(bar.get_x() + bar.get_width() / 2, height),
            xytext=(0, 4),
            textcoords="offset points",
            ha="center",
            va="bottom",
            fontsize=7.5,
            color="#333333",
        )

# Leyenda dentro del gráfico
ax.legend(loc="upper right", frameon=True, facecolor="white", framealpha=0.95)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>&#128187; <font color="#004D40"> Simulación en Python</font>  </3>

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import expon

# 1. Semilla para reproducibilidad
np.random.seed(123)

# 2. Parámetros de la distribución Exponencial
lambda_rate = 0.5  # Parámetro de tasa (lambda)
scale_beta = 1.0 / lambda_rate  # Parámetro de escala (1/lambda)
n_simulations = 10000

# 3. Generación de números uniformes estándar U ~ Unif(0, 1)
U = np.random.random(n_simulations)

# 4. Transformación Inversa analítica: X = -ln(1 - U) / lambda
exponenciales_simuladas = -np.log(1.0 - U) / lambda_rate

# 5. Densidad teórica f(x) = lambda * exp(-lambda * x)
x_vals = np.linspace(0, np.max(exponenciales_simuladas), 500)
pdf_vals = expon.pdf(x_vals, scale=scale_beta)

# 6. Crear figura fija con Matplotlib (Sin errores de Kaleido / 100% visible en GitHub)
fig, ax = plt.subplots(figsize=(8.5, 4.8), dpi=120)

# Histograma empírico (Azul UNAM)
ax.hist(
    exponenciales_simuladas,
    bins=50,
    density=True,
    color="#0F4C81",
    alpha=0.70,
    edgecolor="#082947",
    linewidth=0.8,
    label="Simulación Monte Carlo",
    zorder=2,
)

# Curva de densidad teórica (Rojo Cárdeno)
ax.plot(
    x_vals,
    pdf_vals,
    color="#E63946",
    linewidth=2.5,
    label=r"Densidad Teórica $f(x)$",
    zorder=3,
)

# Personalización del diseño y etiquetas
ax.set_title(
    f"Simulación por Transformación Inversa: Exponencial Exp(\\lambda={lambda_rate})",
    fontsize=11,
    fontweight="bold",
    loc="left",
    pad=12,
)
ax.set_xlabel("Variable aleatoria (x)", fontweight="bold", fontsize=9.5)
ax.set_ylabel("Densidad de Probabilidad", fontweight="bold", fontsize=9.5)

# Grilla y estilo limpio
ax.set_facecolor("white")
fig.patch.set_facecolor("white")
ax.grid(True, color="#E2E8F0", linestyle="-", linewidth=0.8, zorder=0)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_color("#CBD5E1")
ax.spines["bottom"].set_color("#CBD5E1")

# Leyenda
ax.legend(
    loc="upper right",
    frameon=True,
    facecolor="white",
    edgecolor="#CBD5E1",
    fontsize=9,
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### <a id="7"></a><font color="#004D40">1.6 Distribución Binomial negativa</font>

# %% [markdown]
# <table style="width: 100%; border-collapse: collapse; font-family: sans-serif; margin: 20px 0; border-radius: 8px; overflow: hidden; box-shadow: 0 2px 6px rgba(0,0,0,0.08);">
#     <thead>
#         <tr style="background-color: #1B4D3E; color: #FFFFFF; text-align: center; font-size: 1.05em;">
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Función de probabilidad</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Esperanza $\mathbb{E}[X]$</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Varianza $\text{Var}(X)$</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Función Generadora de Momentos</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style="background-color: #F0F7F4; color: #112A21; text-align: center; font-size: 1.25em;">
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle p(y) = \binom{y-1}{r-1}p^r(1-p)^{y-r} \\[4pt] \text{ con } y= r,1,\dots$
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle \lambda$
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle \lambda$
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle exp[\lambda(e^t - 1)]$
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <h3>&#128202; <font color="#004D40">Visualización en Python</font>  </3>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import nbinom

# Configuración del estilo general
sns.set_theme(style="whitegrid", palette="muted")
plt.rcParams.update(
    {
        "font.family": "sans-serif",
        "font.size": 10,
        "axes.labelsize": 11,
        "axes.titlesize": 13,
        "xtick.labelsize": 9,
        "ytick.labelsize": 9,
        "figure.dpi": 150,
    }
)

# 1. Parámetros de la distribución
r_successes = 5  # Número objetivo de éxitos
p_probability = 0.40  # Probabilidad de éxito por ensayo

# Rango de fracasos k a evaluar
mean_theo, var_theo = nbinom.stats(r_successes, p_probability, moments="mv")
std_theo = np.sqrt(var_theo)
k_max = int(mean_theo + 4 * std_theo)
k = np.arange(0, k_max + 1)

# 2. PMF y Estadísticos Teóricos
pmf_nbinom = nbinom.pmf(k, n=r_successes, p=p_probability)
esperanza = mean_theo
varianza = var_theo
desv_est = std_theo

# 3. Creación de la figura
fig, ax = plt.subplots(figsize=(9, 5))

primary_color = "#0F4C81"
edge_color = "#082947"

# Graficado de barras de probabilidad
bars = ax.bar(
    k,
    pmf_nbinom,
    width=0.7,
    color=primary_color,
    edgecolor=edge_color,
    linewidth=1.2,
    alpha=0.85,
    label=f"$X \\sim \\mathrm{{NB}}(r={r_successes}, p={p_probability})$",
)

# Línea para la Esperanza Matemática E[X]
ax.axvline(
    x=esperanza,
    color="#E63946",
    linestyle="--",
    linewidth=2,
    label=f"Esperanza $E[X] = {esperanza:.1f}$ fracasos",
)


# Personalización de ejes
if k_max > 30:
    ax.set_xticks(np.arange(0, k_max + 1, 5))
else:
    ax.set_xticks(k)

ax.set_ylim(0, max(pmf_nbinom) * 1.25)
ax.set_xlabel("Número de fracasos observados ($k$)", fontweight="bold")
ax.set_ylabel("Probabilidad $P(X = k)$", fontweight="bold")

# Título de la gráfica
ax.set_title(
    f"Función de Masa de Probabilidad (PMF) - Binomial Negativa ($r={r_successes}, p={p_probability}$)",
    pad=15,
    fontweight="bold",
)

ax.yaxis.set_major_formatter("{x:.2f}")
ax.grid(True, linestyle=":", alpha=0.5)
sns.despine(top=True, right=True)

# Anotación numérica sobre las barras principales
for bar in bars:
    height = bar.get_height()
    if height >= 0.01:
        ax.annotate(
            f"{height:.3f}",
            xy=(bar.get_x() + bar.get_width() / 2, height),
            xytext=(0, 4),
            textcoords="offset points",
            ha="center",
            va="bottom",
            fontsize=7,
            color="#2D3748",
        )

# Leyenda
ax.legend(
    loc="upper right",
    frameon=True,
    facecolor="white",
    framealpha=0.95,
    fontsize=9,
)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>&#128187; <font color="#004D40"> Simulación en Python</font>  </3>

# %%
import numpy as np
import plotly.graph_objects as go
from scipy.stats import nbinom

# 1. Semilla para reproducibilidad
np.random.seed(123)

# 2. Parámetros de la distribución Binomial Negativa
r_successes = 5  # Número de éxitos requeridos (r)
p_prob = 0.4  # Probabilidad de éxito por ensayo (p)
n_simulations = 10000

# 3. Generación de números uniformes estándar U ~ Unif(0, 1)
U = np.random.random(n_simulations)

# 4. Aplicación de la Transformación Inversa discretizada vía nbinom.ppf
negbinomiales_simuladas = nbinom.ppf(U, n=r_successes, p=p_prob).astype(int)

# 5. Frecuencias relativas observadas en la simulación
unique_vals, counts = np.unique(negbinomiales_simuladas, return_counts=True)
freq_relativas = counts / n_simulations

# 6. Masa de probabilidad teórica PMF
max_k = np.max(unique_vals)
k_vals = np.arange(0, max_k + 1)
pmf_vals = nbinom.pmf(k_vals, n=r_successes, p=p_prob)

# 7. Construcción de la figura interactiva con Plotly
fig = go.Figure()

# Barras de la Simulación Monte Carlo
fig.add_trace(
    go.Bar(
        x=unique_vals,
        y=freq_relativas,
        name="Simulación Monte Carlo",
        marker=dict(
            color="rgba(15, 76, 129, 0.70)",  # Azul Marino UNAM con transparencia
            line=dict(color="#082947", width=1),
        ),
    )
)

# Puntos/Líneas de la Masa Teórica PMF
fig.add_trace(
    go.Scatter(
        x=k_vals,
        y=pmf_vals,
        mode="markers+lines",
        name="Masa Teórica $P(X=k)$",
        marker=dict(color="#E63946", size=8),  # Rojo Cárdeno
        line=dict(color="#E63946", width=2, dash="dash"),
    )
)

# Personalización del diseño (Layout estilizado)
fig.update_layout(
    title=dict(
        text=f"<b>Simulación por Transformación Inversa: Binomial Negativa NegBinom(r={r_successes}, p={p_prob:.2f})</b>",
        font=dict(size=16, family="sans-serif"),
        x=0.05,
    ),
    xaxis=dict(
        title="<b>Número de fracasos antes de r éxitos (k)</b>",
        tickmode="linear",
        tick0=0,
        dtick=2,
        showgrid=True,
        gridcolor="#E2E8F0",
        zeroline=False,
    ),
    yaxis=dict(
        title="<b>Probabilidad / Frecuencia Relativa</b>",
        showgrid=True,
        gridcolor="#E2E8F0",
        zeroline=False,
    ),
    plot_bgcolor="white",
    paper_bgcolor="white",
    bargap=0.20,
    legend=dict(
        x=0.98,
        y=0.98,
        xanchor="right",
        yanchor="top",
        bgcolor="rgba(255, 255, 255, 0.9)",
        bordercolor="#CBD5E1",
        borderwidth=1,
    ),
    width=850,
    height=480,
)

import plotly.io as pio
# Configura Plotly para exportar estático
pio.renderers.default = "png"
fig.show()

# %% [markdown]
# ### <a id="8"></a><font color="#004D40">1.7 Distribución Hipergeométrica</font>

# %% [markdown]
# <table style="width: 100%; border-collapse: collapse; font-family: sans-serif; margin: 20px 0; border-radius: 8px; overflow: hidden; box-shadow: 0 2px 6px rgba(0,0,0,0.08);">
#     <thead>
#         <tr style="background-color: #1B4D3E; color: #FFFFFF; text-align: center; font-size: 1.05em;">
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Función de probabilidad</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Esperanza $\mathbb{E}[X]$</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Varianza $\text{Var}(X)$</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Función Generadora de Momentos</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style="background-color: #F0F7F4; color: #112A21; text-align: center; font-size: 1.25em;">
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle p(y) = \frac{\binom{r}{y}\binom{N-r}{n-y}}{\binom{N}{n}} \\[4pt] \text{ con }\\ y= 0,1,\dots,n \quad\text{si } n \leq r \\ y= 0,1,\dots,r \quad\text{si } n > r $
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle \frac{nr}{N}$
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle n\left(\frac{r}{N}\right)\left(\frac{N-r}{N}\right)\left(\frac{N-n}{N-1}\right)$
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <h3>&#128202; <font color="#004D40">Visualización en Python</font>  </3>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import hypergeom

# Configuración del estilo general
sns.set_theme(style="whitegrid", palette="muted")
plt.rcParams.update(
    {
        "font.family": "sans-serif",
        "font.size": 10,
        "axes.labelsize": 11,
        "axes.titlesize": 13,
        "xtick.labelsize": 9,
        "ytick.labelsize": 9,
        "figure.dpi": 150,
    }
)

# 1. Parámetros de la distribución
N_total = 50      # Tamaño de la población (N)
K_success = 20    # Número de éxitos en la población (K)
n_sample = 12     # Tamaño de la muestra (n)

# Rango de posibles éxitos en la muestra k
k_min = max(0, n_sample - (N_total - K_success))
k_max = min(n_sample, K_success)
k = np.arange(k_min, k_max + 1)

# 2. PMF y Estadísticos Teóricos
# En scipy: hypergeom(M, n, N) donde M=población, n=éxitos pob, N=muestra
pmf_hyper = hypergeom.pmf(k, N_total, K_success, n_sample)
mean_theo, var_theo = hypergeom.stats(N_total, K_success, n_sample, moments="mv")
esperanza = mean_theo
varianza = var_theo
desv_est = np.sqrt(varianza)

# 3. Creación de la figura
fig, ax = plt.subplots(figsize=(8.5, 4.8))

primary_color = "#0F4C81"
edge_color = "#082947"

# Graficado de barras de probabilidad
bars = ax.bar(
    k,
    pmf_hyper,
    width=0.6,
    color=primary_color,
    edgecolor=edge_color,
    linewidth=1.2,
    alpha=0.85,
    label=f"$X \\sim \\mathrm{{HG}}(N={N_total}, K={K_success}, n={n_sample})$",
)

# Línea para la Esperanza Matemática E[X]
ax.axvline(
    x=esperanza,
    color="#E63946",
    linestyle="--",
    linewidth=1.8,
    label=f"Esperanza $E[X] = {esperanza:.2f}$ éxitos",
)

# Personalización de ejes
ax.set_xticks(k)
ax.set_ylim(0, max(pmf_hyper) * 1.25)
ax.set_xlabel("Número de éxitos en la muestra ($k$)", fontweight="bold")
ax.set_ylabel("Probabilidad $P(X = k)$", fontweight="bold")

# Título de la gráfica
ax.set_title(
    f"Función de Masa de Probabilidad (PMF) - Distribución Hipergeométrica",
    pad=15,
    fontweight="bold",
)

ax.yaxis.set_major_formatter("{x:.2f}")
ax.grid(True, linestyle=":", alpha=0.6)
sns.despine(top=True, right=True)

# Anotación numérica sobre cada barra
for bar in bars:
    height = bar.get_height()
    if height >= 0.005:
        ax.annotate(
            f"{height:.3f}",
            xy=(bar.get_x() + bar.get_width() / 2, height),
            xytext=(0, 4),
            textcoords="offset points",
            ha="center",
            va="bottom",
            fontsize=7.5,
            color="#333333",
        )

# Leyenda
ax.legend(
    loc="upper right",
    frameon=True,
    facecolor="white",
    framealpha=0.95,
    fontsize=9,
)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>&#128187; <font color="#004D40"> Simulación en Python</font>  </3>

# %%
import numpy as np
import plotly.graph_objects as go
from scipy.stats import hypergeom

# 1. Semilla para reproducibilidad
np.random.seed(123)

# 2. Parámetros de la distribución Hipergeométrica
M_pop = 50  # Tamaño total de la población (M)
n_success_pop = 20  # Total de elementos de éxito en la población (n)
N_sample = 12  # Tamaño de la muestra extraída sin reemplazo (N)
n_simulations = 10000

# 3. Generación de números uniformes estándar U ~ Unif(0, 1)
U = np.random.random(n_simulations)

# 4. Aplicación de la Transformación Inversa discretizada vía hypergeom.ppf
hipergeometricas_simuladas = hypergeom.ppf(
    U, M=M_pop, n=n_success_pop, N=N_sample
).astype(int)

# 5. Frecuencias relativas observadas en la simulación
unique_vals, counts = np.unique(hipergeometricas_simuladas, return_counts=True)
freq_relativas = counts / n_simulations

# 6. Masa de probabilidad teórica PMF
min_k = np.min(unique_vals)
max_k = np.max(unique_vals)
k_vals = np.arange(min_k, max_k + 1)
pmf_vals = hypergeom.pmf(k_vals, M=M_pop, n=n_success_pop, N=N_sample)

# 7. Construcción de la figura interactiva con Plotly
fig = go.Figure()

# Barras de la Simulación Monte Carlo
fig.add_trace(
    go.Bar(
        x=unique_vals,
        y=freq_relativas,
        name="Simulación Monte Carlo",
        marker=dict(
            color="rgba(15, 76, 129, 0.70)",  # Azul Marino UNAM con transparencia
            line=dict(color="#082947", width=1),
        ),
    )
)

# Puntos/Líneas de la Masa Teórica PMF
fig.add_trace(
    go.Scatter(
        x=k_vals,
        y=pmf_vals,
        mode="markers+lines",
        name="Masa Teórica $P(X=k)$",
        marker=dict(color="#E63946", size=8),  # Rojo Cárdeno
        line=dict(color="#E63946", width=2, dash="dash"),
    )
)

# Personalización del diseño (Layout estilizado)
fig.update_layout(
    title=dict(
        text=f"<b>Simulación por Transformación Inversa: Hipergeométrica Hypergeom(M={M_pop}, n={n_success_pop}, N={N_sample})</b>",
        font=dict(size=16, family="sans-serif"),
        x=0.05,
    ),
    xaxis=dict(
        title="<b>Número de éxitos observados en la muestra (k)</b>",
        tickmode="linear",
        tick0=0,
        dtick=1,
        showgrid=True,
        gridcolor="#E2E8F0",
        zeroline=False,
    ),
    yaxis=dict(
        title="<b>Probabilidad / Frecuencia Relativa</b>",
        showgrid=True,
        gridcolor="#E2E8F0",
        zeroline=False,
    ),
    plot_bgcolor="white",
    paper_bgcolor="white",
    bargap=0.20,
    legend=dict(
        x=0.98,
        y=0.98,
        xanchor="right",
        yanchor="top",
        bgcolor="rgba(255, 255, 255, 0.9)",
        bordercolor="#CBD5E1",
        borderwidth=1,
    ),
    width=850,
    height=480,
)

import plotly.io as pio
# Configura Plotly para exportar estático
pio.renderers.default = "png"
fig.show()

# %% [markdown]
# ## <a id="9"></a><font color="#2F855A">2. Variables aleatorias continuas</font>

# %% [markdown]
# ### <a id="10"></a><font color="#004D40">2.1 Distribución Uniforme Continua</font>

# %% [markdown]
# <table style="width: 100%; border-collapse: collapse; font-family: sans-serif; margin: 20px 0; border-radius: 8px; overflow: hidden; box-shadow: 0 2px 6px rgba(0,0,0,0.08);">
#     <thead>
#         <tr style="background-color: #1B4D3E; color: #FFFFFF; text-align: center; font-size: 1.05em;">
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Función de probabilidad</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Esperanza $\mathbb{E}[X]$</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Varianza $\text{Var}(X)$</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Función Generadora de Momentos</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style="background-color: #F0F7F4; color: #112A21; text-align: center; font-size: 1.25em;">
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle f(y)=\frac{1}{\theta_2-\theta_1} \\ \text{con } \theta_1 \leq y \leq \theta_2 $
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle \frac{\theta_1 + \theta_2}{2}$
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle \frac{(\theta_2 - \theta_1)^2}{12}$
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle \frac{e^{t\theta_2}-e^{t\theta_1}}{t(\theta_2 - \theta_1)}$
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <h3>&#128202; <font color="#004D40">Visualización en Python</font>  </3>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import uniform

# Configuración del estilo general
sns.set_theme(style="whitegrid", palette="muted")
plt.rcParams.update(
    {
        "font.family": "sans-serif",
        "font.size": 10,
        "axes.labelsize": 11,
        "axes.titlesize": 13,
        "xtick.labelsize": 9,
        "ytick.labelsize": 9,
        "figure.dpi": 150,
    }
)

# 1. Parámetros de la distribución continua
a = 2.0  # Límite inferior
b = 10.0  # Límite superior

# 2. Rejilla de puntos x
# Extendemos la rejilla antes de 'a' y después de 'b' para visibilizar el paso a cero
padding = (b - a) * 0.25
x = np.linspace(a - padding, b + padding, 1000)

# 3. PDF y Estadísticos Teóricos
# En scipy.stats.uniform: loc = a, scale = b - a
pdf_unif = uniform.pdf(x, loc=a, scale=b - a)
esperanza = (a + b) / 2.0
varianza = ((b - a) ** 2) / 12.0
desv_est = np.sqrt(varianza)
altura_pdf = 1.0 / (b - a)

# 4. Creación de la figura
fig, ax = plt.subplots(figsize=(8.5, 4.8))

primary_color = "#0F4C81"
edge_color = "#082947"

# Graficado de la curva de densidad (PDF)
ax.plot(
    x,
    pdf_unif,
    color=primary_color,
    linewidth=2.5,
    label=f"$X \\sim \\mathrm{{Unif}}(a={a:.1f}, b={b:.1f})$",
)

# Sombreado del área bajo la curva en el intervalo [a, b]
ax.fill_between(
    x,
    pdf_unif,
    where=((x >= a) & (x <= b)),
    color=primary_color,
    alpha=0.25,
)

# Línea vertical para la Esperanza Matemática E[X]
ax.axvline(
    x=esperanza,
    color="#E63946",
    linestyle="--",
    linewidth=1.8,
    label=f"Esperanza $E[X] = {esperanza:.1f}$",
)


# Línea guía horizontal para la altura fija f(x) = 1/(b-a)
ax.axhline(
    y=altura_pdf,
    color=edge_color,
    linestyle=":",
    linewidth=1.2,
    alpha=0.6,
)

# Personalización de ejes
ax.set_ylim(0, altura_pdf * 1.4)
ax.set_xlim(a - padding, b + padding)
ax.set_xlabel("Variable aleatoria continua ($x$)", fontweight="bold")
ax.set_ylabel("Densidad de probabilidad $f(x)$", fontweight="bold")

# Título de la gráfica
ax.set_title(
    "Función de Densidad de Probabilidad (PDF) - Distribución Uniforme Continua",
    pad=15,
    fontweight="bold",
)

ax.yaxis.set_major_formatter("{x:.3f}")
ax.grid(True, linestyle=":", alpha=0.6)
sns.despine(top=True, right=True)

# Leyenda
ax.legend(
    loc="upper right",
    frameon=True,
    facecolor="white",
    framealpha=0.95,
    fontsize=9,
)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>&#128187; <font color="#004D40"> Simulación en Python</font>  </3>

# %%
import numpy as np
import plotly.graph_objects as go

# 1. Semilla para reproducibilidad
np.random.seed(123)

# 2. Parámetros del experimento
a_param = 5.0
b_param = 15.0
n_simulations = 10000

# 3. Generación de números uniformes estándar U ~ Unif(0, 1)
U = np.random.random(n_simulations)

# 4. Aplicación de la Transformación Inversa: X = a + (b - a) * U
uniformes_simuladas = a_param + (b_param - a_param) * U

# 5. Densidad teórica f(x) = 1 / (b - a)
x_vals = np.linspace(a_param - 2, b_param + 2, 500)
y_vals = np.where(
    (x_vals >= a_param) & (x_vals <= b_param), 1.0 / (b_param - a_param), 0.0
)

# 6. Construcción de la figura interactiva con Plotly
fig = go.Figure()

# Histograma empírico normalizado como densidad de probabilidad
fig.add_trace(
    go.Histogram(
        x=uniformes_simuladas,
        nbinsx=40,
        histnorm="probability density",
        name="Simulación Monte Carlo",
        marker=dict(
            color="rgba(15, 76, 129, 0.70)",  # Azul Marino UNAM con transparencia
            line=dict(color="#082947", width=1),
        ),
    )
)

# Curva/Línea de la densidad teórica f(x)
fig.add_trace(
    go.Scatter(
        x=x_vals,
        y=y_vals,
        mode="lines",
        name="Densidad Teórica $f(x)$",
        line=dict(color="#E63946", width=3),  # Rojo Cárdeno
    )
)

# Personalización del diseño (Layout estilizado)
fig.update_layout(
    title=dict(
        text="<b>Simulación por Transformación Inversa: Uniforme Continua Unif(5, 15)</b>",
        font=dict(size=16, family="sans-serif"),
        x=0.05,
    ),
    xaxis=dict(
        title="<b>Variable aleatoria (x)</b>",
        showgrid=True,
        gridcolor="#E2E8F0",
        zeroline=False,
    ),
    yaxis=dict(
        title="<b>Densidad de Probabilidad</b>",
        showgrid=True,
        gridcolor="#E2E8F0",
        zeroline=False,
    ),
    plot_bgcolor="white",
    paper_bgcolor="white",
    bargap=0.05,
    legend=dict(
        x=0.98,
        y=0.98,
        xanchor="right",
        yanchor="top",
        bgcolor="rgba(255, 255, 255, 0.9)",
        bordercolor="#CBD5E1",
        borderwidth=1,
    ),
    width=850,
    height=480,
)

import plotly.io as pio
# Configura Plotly para exportar estático
pio.renderers.default = "png"
fig.show()

# %% [markdown]
# ### <a id="11"></a><font color="#004D40">2.2 Distribución Normal</font>

# %% [markdown]
# <table style="width: 100%; border-collapse: collapse; font-family: sans-serif; margin: 20px 0; border-radius: 8px; overflow: hidden; box-shadow: 0 2px 6px rgba(0,0,0,0.08);">
#     <thead>
#         <tr style="background-color: #1B4D3E; color: #FFFFFF; text-align: center; font-size: 1.05em;">
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Función de probabilidad</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Esperanza $\mathbb{E}[X]$</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Varianza $\text{Var}(X)$</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Función Generadora de Momentos</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style="background-color: #F0F7F4; color: #112A21; text-align: center; font-size: 1.25em;">
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle f(y)=\frac{1}{\theta_2-\theta_1} \\ \text{con } \theta_1 \leq y \leq \theta_2 $
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle \frac{\theta_1 + \theta_2}{2}$
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle \frac{(\theta_2 - \theta_1)^2}{12}$
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle \frac{e^{t\theta_2}-e^{t\theta_1}}{t(\theta_2 - \theta_1)}$
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <h3>&#128202; <font color="#004D40">Visualización en Python</font>  </3>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import norm

# Configuración del estilo general para GitHub Notebooks
sns.set_theme(style="whitegrid", palette="muted")
plt.rcParams.update(
    {
        "font.family": "sans-serif",
        "font.size": 10,
        "axes.labelsize": 11,
        "axes.titlesize": 13,
        "xtick.labelsize": 9,
        "ytick.labelsize": 9,
        "figure.dpi": 150,
    }
)

# 1. Parámetros de la distribución
mu = 10.0      # Media / Esperanza
sigma = 2.5    # Desviación estándar
varianza = sigma**2

# 2. Rejilla de puntos x (rango de 4 desviaciones estándar alrededor de la media)
x = np.linspace(mu - 4 * sigma, mu + 4 * sigma, 1000)

# 3. PDF y Estadísticos Teóricos
pdf_norm = norm.pdf(x, loc=mu, scale=sigma)
esperanza = mu
desv_est = sigma

# 4. Creación de la figura
fig, ax = plt.subplots(figsize=(8.5, 4.8))

primary_color = "#0F4C81"
edge_color = "#082947"

# Graficado de la curva de densidad (PDF)
ax.plot(
    x,
    pdf_norm,
    color=primary_color,
    linewidth=2.5,
    label=rf"$X \sim \mathcal{{N}}(\mu={mu:.1f}, \sigma^2={varianza:.2f})$",
)

# Sombreado bajo toda la curva
ax.fill_between(
    x,
    pdf_norm,
    color=primary_color,
    alpha=0.15,
)

# Línea vertical para la Esperanza Matemática E[X] = mu
ax.axvline(
    x=esperanza,
    color="#E63946",
    linestyle="--",
    linewidth=1.8,
    label=f"Esperanza $E[X] = \\mu = {esperanza:.1f}$",
)

# Indicadores visuales punteados para +/- 2 sigma
ax.axvline(esperanza - 2 * sigma, color="#555555", linestyle=":", alpha=0.6)
ax.axvline(esperanza + 2 * sigma, color="#555555", linestyle=":", alpha=0.6)

# Personalización de ejes
ax.set_ylim(0, max(pdf_norm) * 1.25)
ax.set_xlim(mu - 4 * sigma, mu + 4 * sigma)
ax.set_xlabel("Variable aleatoria continua ($x$)", fontweight="bold")
ax.set_ylabel("Densidad de probabilidad $f(x)$", fontweight="bold")

# Título de la gráfica
ax.set_title(
    f"Función de Densidad de Probabilidad (PDF) - Distribución Normal ($\\mu={mu:.1f}, \\sigma={sigma:.1f}$)",
    pad=15,
    fontweight="bold",
)

ax.yaxis.set_major_formatter("{x:.3f}")
ax.grid(True, linestyle=":", alpha=0.6)
sns.despine(top=True, right=True)

# Leyenda dentro del gráfico
ax.legend(
    loc="upper right",
    frameon=True,
    facecolor="white",
    framealpha=0.95,
    fontsize=9,
)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>&#128187; <font color="#004D40"> Simulación en Python</font>  </3>

# %%
import numpy as np
import plotly.graph_objects as go
from scipy.stats import norm

# 1. Semilla para reproducibilidad
np.random.seed(123)

# 2. Parámetros de la distribución normal
mu_param = 10.0
sigma_param = 2.5
n_simulations = 10000

# 3. Generación de números uniformes estándar U ~ Unif(0, 1)
U = np.random.random(n_simulations)

# 4. Aplicación de la Transformación Inversa: X = mu + sigma * Phi^{-1}(U)
normales_simuladas = norm.ppf(U, loc=mu_param, scale=sigma_param)

# 5. Densidad teórica f(x)
x_vals = np.linspace(
    mu_param - 4 * sigma_param, mu_param + 4 * sigma_param, 500
)
y_vals = norm.pdf(x_vals, loc=mu_param, scale=sigma_param)

# 6. Construcción de la figura interactiva con Plotly
fig = go.Figure()

# Histograma empírico normalizado como densidad de probabilidad
fig.add_trace(
    go.Histogram(
        x=normales_simuladas,
        nbinsx=50,
        histnorm="probability density",
        name="Simulación Monte Carlo",
        marker=dict(
            color="rgba(15, 76, 129, 0.70)",  # Azul Marino UNAM con transparencia
            line=dict(color="#082947", width=1),
        ),
    )
)

# Curva de la densidad teórica f(x)
fig.add_trace(
    go.Scatter(
        x=x_vals,
        y=y_vals,
        mode="lines",
        name="Densidad Teórica $f(x)$",
        line=dict(color="#E63946", width=3),  # Rojo Cárdeno
    )
)

# Personalización del diseño (Layout estilizado)
fig.update_layout(
    title=dict(
        text=f"<b>Simulación por Transformación Inversa: Normal N({mu_param:.1f}, {sigma_param**2:.2f})</b>",
        font=dict(size=16, family="sans-serif"),
        x=0.05,
    ),
    xaxis=dict(
        title="<b>Variable aleatoria (x)</b>",
        showgrid=True,
        gridcolor="#E2E8F0",
        zeroline=False,
    ),
    yaxis=dict(
        title="<b>Densidad de Probabilidad</b>",
        showgrid=True,
        gridcolor="#E2E8F0",
        zeroline=False,
    ),
    plot_bgcolor="white",
    paper_bgcolor="white",
    bargap=0.05,
    legend=dict(
        x=0.98,
        y=0.98,
        xanchor="right",
        yanchor="top",
        bgcolor="rgba(255, 255, 255, 0.9)",
        bordercolor="#CBD5E1",
        borderwidth=1,
    ),
    width=850,
    height=480,
)

import plotly.io as pio
# Configura Plotly para exportar estático
pio.renderers.default = "png"
fig.show()

# %% [markdown]
# ### <a id="12"></a><font color="#004D40">2.3 Distribución Exponencial</font>

# %% [markdown]
# <table style="width: 100%; border-collapse: collapse; font-family: sans-serif; margin: 20px 0; border-radius: 8px; overflow: hidden; box-shadow: 0 2px 6px rgba(0,0,0,0.08);">
#     <thead>
#         <tr style="background-color: #1B4D3E; color: #FFFFFF; text-align: center; font-size: 1.05em;">
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Función de probabilidad</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Esperanza $\mathbb{E}[X]$</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Varianza $\text{Var}(X)$</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Función Generadora de Momentos</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style="background-color: #F0F7F4; color: #112A21; text-align: center; font-size: 1.25em;">
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle f(y)=\frac{1}{\beta}e^{-y/\beta} \\ \text{con } \beta> 0 \\ 0 < y < \infty $
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle \beta$
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle \beta^2$
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle (1-\beta t)^{-1}$
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <h3>&#128202; <font color="#004D40">Visualización en Python</font>  </3>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import expon

# Configuración del estilo general para GitHub Notebooks (UNAM Style)
sns.set_theme(style="whitegrid", palette="muted")
plt.rcParams.update(
    {
        "font.family": "sans-serif",
        "font.size": 10,
        "axes.labelsize": 11,
        "axes.titlesize": 13,
        "xtick.labelsize": 9,
        "ytick.labelsize": 9,
        "figure.dpi": 150,  # Alta resolución para visualización web
    }
)

# 1. Parámetros de la distribución continua
lam_rate = 0.5      # Parámetro de tasa (lambda)
scale_param = 1.0 / lam_rate # Scipy usa el parámetro de escala (1/lambda)

# 2. Rejilla de puntos x
# Definimos el rango desde 0 hasta cubrir aprox. el 99% de la probabilidad
x_max = expon.ppf(0.99, scale=scale_param)
x = np.linspace(0, x_max, 1000)

# 3. PDF y Estadísticos Teóricos
# En scipy.stats.expon: loc=0 (por defecto, inicio en 0), scale=1/lambda
pdf_expon = expon.pdf(x, scale=scale_param)
mean_theo, var_theo = expon.stats(scale=scale_param, moments="mv")
esperanza = mean_theo
desv_est = np.sqrt(var_theo)

# 4. Creación de la figura
fig, ax = plt.subplots(figsize=(8.5, 4.8))

primary_color = "#0F4C81" # Azul Marino UNAM
edge_color = "#082947"

# Graficado de la curva de densidad (PDF)
ax.plot(
    x,
    pdf_expon,
    color=primary_color,
    linewidth=2.5,
    label=rf"$X \sim \mathrm{{Exp}}(\lambda={lam_rate:.1f})$",
)

# Sombreado bajo la curva f(x)
ax.fill_between(
    x,
    pdf_expon,
    color=primary_color,
    alpha=0.20,
)

# Línea vertical para la Esperanza Matemática E[X] = 1/lambda
ax.axvline(
    x=esperanza,
    color="#E63946", # Rojo Cárdeno
    linestyle="--",
    linewidth=1.8,
    label=f"Esperanza $E[X] = 1/\lambda = {esperanza:.1f}$",
)

# Personalización de ejes
ax.set_ylim(0, max(pdf_expon) * 1.15) # Pequeño margen superior
ax.set_xlim(0, x_max)
ax.set_xlabel("Variable aleatoria continua: Tiempo ($x$)", fontweight="bold")
ax.set_ylabel("Densidad de probabilidad $f(x)$", fontweight="bold")

# Título de la gráfica
ax.set_title(
    f"Función de Densidad de Probabilidad (PDF) - Distribución Exponencial ($\lambda={lam_rate:.1f}$)",
    pad=15,
    fontweight="bold",
)

ax.yaxis.set_major_formatter("{x:.3f}")
ax.grid(True, linestyle=":", alpha=0.6)
sns.despine(top=True, right=True)

# Leyenda dentro del gráfico
ax.legend(
    loc="upper right",
    frameon=True,
    facecolor="white",
    framealpha=0.95,
    fontsize=9,
)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>&#128187; <font color="#004D40"> Simulación en Python</font>  </3>

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import expon

# 1. Semilla para reproducibilidad
np.random.seed(123)

# 2. Parámetros de la distribución Exponencial
lambda_rate = 0.5  # Parámetro de tasa (lambda)
scale_beta = 1.0 / lambda_rate  # Parámetro de escala (1/lambda)
n_simulations = 10000

# 3. Generación de números uniformes estándar U ~ Unif(0, 1)
U = np.random.random(n_simulations)

# 4. Transformación Inversa analítica: X = -ln(1 - U) / lambda
exponenciales_simuladas = -np.log(1.0 - U) / lambda_rate

# 5. Densidad teórica f(x) = lambda * exp(-lambda * x)
x_vals = np.linspace(0, np.max(exponenciales_simuladas), 500)
pdf_vals = expon.pdf(x_vals, scale=scale_beta)

# 6. Crear figura fija con Matplotlib (Sin errores de Kaleido / 100% visible en GitHub)
fig, ax = plt.subplots(figsize=(8.5, 4.8), dpi=120)

# Histograma empírico (Azul UNAM)
ax.hist(
    exponenciales_simuladas,
    bins=50,
    density=True,
    color="#0F4C81",
    alpha=0.70,
    edgecolor="#082947",
    linewidth=0.8,
    label="Simulación Monte Carlo",
    zorder=2,
)

# Curva de densidad teórica (Rojo Cárdeno)
ax.plot(
    x_vals,
    pdf_vals,
    color="#E63946",
    linewidth=2.5,
    label=r"Densidad Teórica $f(x)$",
    zorder=3,
)

# Personalización del diseño y etiquetas
ax.set_title(
    f"Simulación por Transformación Inversa: Exponencial Exp(\\lambda={lambda_rate})",
    fontsize=11,
    fontweight="bold",
    loc="left",
    pad=12,
)
ax.set_xlabel("Variable aleatoria (x)", fontweight="bold", fontsize=9.5)
ax.set_ylabel("Densidad de Probabilidad", fontweight="bold", fontsize=9.5)

# Grilla y estilo limpio
ax.set_facecolor("white")
fig.patch.set_facecolor("white")
ax.grid(True, color="#E2E8F0", linestyle="-", linewidth=0.8, zorder=0)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_color("#CBD5E1")
ax.spines["bottom"].set_color("#CBD5E1")

# Leyenda
ax.legend(
    loc="upper right",
    frameon=True,
    facecolor="white",
    edgecolor="#CBD5E1",
    fontsize=9,
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### <a id="13"></a><font color="#004D40">2.4 Distribución Gamma</font>

# %% [markdown]
# <table style="width: 100%; border-collapse: collapse; font-family: sans-serif; margin: 20px 0; border-radius: 8px; overflow: hidden; box-shadow: 0 2px 6px rgba(0,0,0,0.08);">
#     <thead>
#         <tr style="background-color: #1B4D3E; color: #FFFFFF; text-align: center; font-size: 1.05em;">
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Función de probabilidad</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Esperanza $\mathbb{E}[X]$</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Varianza $\text{Var}(X)$</th>
#             <th style="padding: 15px 15px; border: 1px solid #13382C;">Función Generadora de Momentos</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr style="background-color: #F0F7F4; color: #112A21; text-align: center; font-size: 1.25em;">
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle f(y)= \left[ \frac{1}{\Gamma (\alpha)\beta^\alpha} \right]y^{\alpha - 1}e^{-y/\beta} \\ \text{con } 0 < y < \infty $
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle \alpha\beta$
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle \alpha\beta^2$
#             </td>
#             <td style="padding: 15px 15px; border: 1px solid #D1E5DC;">
#                 $\displaystyle (1-\beta t)^{-\alpha}$
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <h3>&#128202; <font color="#004D40">Visualización en Python</font>  </3>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import gamma

# Configuración del estilo general
sns.set_theme(style="whitegrid", palette="muted")
plt.rcParams.update(
    {
        "font.family": "sans-serif",
        "font.size": 10,
        "axes.labelsize": 11,
        "axes.titlesize": 13,
        "xtick.labelsize": 9,
        "ytick.labelsize": 9,
        "figure.dpi": 150,
    }
)

# 1. Parámetros de la distribución continua
alpha_shape = 3.0  # Parámetro de forma (a)
theta_scale = 2.0  # Parámetro de escala (scale)

# 2. Rejilla de puntos x (cubre > 99.5% de la probabilidad)
x_max = gamma.ppf(0.995, a=alpha_shape, scale=theta_scale)
x = np.linspace(0, x_max, 1000)

# 3. PDF y Estadísticos Teóricos
# En scipy.stats.gamma: a = alpha, scale = theta
pdf_gamma = gamma.pdf(x, a=alpha_shape, scale=theta_scale)
mean_theo, var_theo = gamma.stats(a=alpha_shape, scale=theta_scale, moments="mv")
esperanza = mean_theo
varianza = var_theo
desv_est = np.sqrt(varianza)

# 4. Creación de la figura
fig, ax = plt.subplots(figsize=(8.5, 4.8))

primary_color = "#0F4C81"
edge_color = "#082947"

# Graficado de la curva de densidad (PDF)
ax.plot(
    x,
    pdf_gamma,
    color=primary_color,
    linewidth=2.5,
    label=rf"$X \sim \mathrm{{Gamma}}(\alpha={alpha_shape:.1f}, \theta={theta_scale:.1f})$",
)

# Sombreado bajo la curva f(x)
ax.fill_between(
    x,
    pdf_gamma,
    color=primary_color,
    alpha=0.20,
)

# Línea vertical para la Esperanza Matemática E[X]
ax.axvline(
    x=esperanza,
    color="#E63946",
    linestyle="--",
    linewidth=1.8,
    label=f"Esperanza $E[X] = \\alpha\\theta = {esperanza:.1f}$",
)

# Personalización de ejes
ax.set_ylim(0, max(pdf_gamma) * 1.2)
ax.set_xlim(0, x_max)
ax.set_xlabel("Variable aleatoria continua ($x$)", fontweight="bold")
ax.set_ylabel("Densidad de probabilidad $f(x)$", fontweight="bold")

# Título de la gráfica
ax.set_title(
    f"Función de Densidad de Probabilidad (PDF) - Distribución Gamma ($\\alpha={alpha_shape:.1f}, \\theta={theta_scale:.1f}$)",
    pad=15,
    fontweight="bold",
)

ax.yaxis.set_major_formatter("{x:.3f}")
ax.grid(True, linestyle=":", alpha=0.6)
sns.despine(top=True, right=True)

# Leyenda dentro del gráfico
ax.legend(
    loc="upper right",
    frameon=True,
    facecolor="white",
    framealpha=0.95,
    fontsize=9,
)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>&#128187; <font color="#004D40"> Simulación en Python</font>  </3>

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import gamma

# 1. Semilla para reproducibilidad
np.random.seed(123)

# 2. Parámetros de la distribución Gamma
alpha_param = 3.0  # Forma (shape / k)
beta_scale = 2.0  # Escala (scale / theta). Nota: si usas tasa (rate), scale = 1/rate
n_simulations = 10000

# 3. Generación de números uniformes estándar U ~ Unif(0, 1)
U = np.random.random(n_simulations)

# 4. Transformación Inversa discretizada/continua vía gamma.ppf
gamma_simuladas = gamma.ppf(U, a=alpha_param, scale=beta_scale)

# 5. Densidad teórica f(x)
x_vals = np.linspace(0, np.max(gamma_simuladas), 500)
pdf_vals = gamma.pdf(x_vals, a=alpha_param, scale=beta_scale)

# 6. Crear figura fija con Matplotlib (Sin errores de Kaleido / 100% visible en GitHub)
fig, ax = plt.subplots(figsize=(8.5, 4.8), dpi=120)

# Histograma empírico (Azul UNAM)
ax.hist(
    gamma_simuladas,
    bins=50,
    density=True,
    color="#0F4C81",
    alpha=0.70,
    edgecolor="#082947",
    linewidth=0.8,
    label="Simulación Monte Carlo",
    zorder=2,
)

# Curva de densidad teórica (Rojo Cárdeno)
ax.plot(
    x_vals,
    pdf_vals,
    color="#E63946",
    linewidth=2.5,
    label=r"Densidad Teórica $f(x)$",
    zorder=3,
)

# Personalización del diseño y etiquetas
ax.set_title(
    f"Simulación por Transformación Inversa: Gamma(\\alpha={alpha_param}, \\theta={beta_scale})",
    fontsize=11,
    fontweight="bold",
    loc="left",
    pad=12,
)
ax.set_xlabel("Variable aleatoria (x)", fontweight="bold", fontsize=9.5)
ax.set_ylabel("Densidad de Probabilidad", fontweight="bold", fontsize=9.5)

# Grilla y estilo limpio
ax.set_facecolor("white")
fig.patch.set_facecolor("white")
ax.grid(True, color="#E2E8F0", linestyle="-", linewidth=0.8, zorder=0)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_color("#CBD5E1")
ax.spines["bottom"].set_color("#CBD5E1")

# Leyenda
ax.legend(
    loc="upper right",
    frameon=True,
    facecolor="white",
    edgecolor="#CBD5E1",
    fontsize=9,
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## <a id="14"></a><font color="#2F855A">3. Función Generadora de Momentos (FGM)</font>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Definición:</b> La <b>función generadora de momento</b> $m(t)$ para una variable aleatoria $Y$ se define como
#     $$m(t) = E(e^{tY}) $$. Decimos que una función generadora de momento para Y existe si existe una constante positiva $b$ tal que $m(t)$ es finita para $|t| \leq b$.
#     <div style="text-align: right; margin-top: 10px; font-size: 0.9em; color: #1A365D;">
#         <i>(Wackerly et al, 2010, p. 139)</i>
#     </div>
# </div>

# %% [markdown]
# ## <a id="15"></a><font color="#2F855A">4. Función Característica (FC)</font>

# %% [markdown]
# $$
# \varphi_X(t)=\mathbb{E}(e^{itX})
# $$
#
# La función característica siempre existe y caracteriza completamente la distribución.

# %% [markdown]
# ## <a id="16"></a><font color="#2F855A">5. Ley de los grandes Números</font>

# %% [markdown]
# Desde el siglo XVI, Gerolano Cardano observó que la precisión de las estadísticas empíricas incrementa con el número de ibservaciones. Bernoulli y Poisson retomaron esa idea y la retomaron con la ley de los grandes números, misma que posteriormente fue generalizada por matemáticos dedicados a la probabilidad (Rincón, 2014).

# %% [markdown]
# <div style="background-color: #F3E8FF; padding: 15px; border-radius: 6px; margin: 15px 0;">
#     <b style="color: #581C87; font-size: 1.05em;">Teorema (Ley de los grandes números):</b>
#     Sea $X_1, X_2, \dots$ una sucesión infinita de variables aleatorias independientes e idénticamente distribuidas con media finita $\mu$. Entonces, cuando $n \to \infty$,
#     $$\frac{1}{n} \sum_{i=1}^{n} X_i \to \mu$$
#     en donde la convergencia se verifica en el sentido casi seguro (ley fuerte) y también en probabilidad (ley débil).
#     <div style="text-align: right; margin-top: 10px; font-size: 0.9em; color: #6B21A8;">
#         <i>(Rincón, 2014, p. 368)</i>
#     </div>
# </div>

# %% [markdown]
# <h3>&#128187; <font color="#004D40"> Simulación en Python</font>  </3>

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. Semilla para reproducibilidad
np.random.seed(123)

# 2. Parámetros del experimento (Lanzamiento de un dado justo)
n_simulations = 10000
mu_teorico = 3.5
n_trayectorias = 5
eje_n = np.arange(1, n_simulations + 1)

# Paleta de 5 colores distintos para las trayectorias
colores_trayectorias = ["#0F4C81", "#2A9D8F", "#E76F51", "#F4A261", "#9B5DE5"]

# 3. Crear figura fija con Matplotlib (Visible y fija en GitHub)
fig, ax = plt.subplots(figsize=(8.5, 4.8), dpi=120)

# 4. Generar y graficar cada simulación con su propio color
for i in range(n_trayectorias):
    lanzamientos = np.random.randint(1, 7, size=n_simulations)
    promedios_acumulados = np.cumsum(lanzamientos) / eje_n

    ax.plot(
        eje_n,
        promedios_acumulados,
        color=colores_trayectorias[i],
        linewidth=1.4,
        alpha=0.85,
        label=f"Simulación {i + 1}",
        zorder=3,
    )

# 5. Línea horizontal de Esperanza Teórica E[X] = 3.5
ax.axhline(
    y=mu_teorico,
    color="#E63946",
    linestyle="--",
    linewidth=2.2,
    label=rf"Esperanza Teórica $E[X] = {mu_teorico}$",
    zorder=4,
)

# 6. Personalización del diseño y etiquetas
ax.set_title(
    "Ley de los Grandes Números: Convergencia de Múltiples Simulaciones",
    fontsize=11,
    fontweight="bold",
    loc="left",
    pad=12,
)
ax.set_xlabel("Tamaño de la muestra (n)", fontweight="bold", fontsize=9.5)
ax.set_ylabel(
    r"Promedio Acumulado ($\bar{X}_n$)", fontweight="bold", fontsize=9.5
)

# Ajuste de límites verticales para observar las oscilaciones
ax.set_ylim(2.0, 5.0)

# Formato visual limpio
ax.set_facecolor("white")
fig.patch.set_facecolor("white")
ax.grid(True, color="#E2E8F0", linestyle="-", linewidth=0.8, zorder=0)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_color("#CBD5E1")
ax.spines["bottom"].set_color("#CBD5E1")

# Leyenda
ax.legend(
    loc="upper right",
    frameon=True,
    facecolor="white",
    edgecolor="#CBD5E1",
    fontsize=8.5,
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## <a id="17"></a><font color="#2F855A">6. Teorema Central del Límite</font>

# %% [markdown]
# <div style="background-color: #F3E8FF; padding: 15px; border-radius: 6px; margin: 15px 0;">
#     <b style="color: #581C87; font-size: 1.05em;">Teorema (Teorema central del límite):</b>
#     Sea $X_1, X_2, \dots$ una sucesión infinita de variables aleatorias independientes e idénticamente distribuidas con media $\mu$ y varianza finita $\sigma^2$. Entonces la función de distribución de la variable aleatoria
#     $$ Z_n = \frac{(X_1+\dots+X_n)-n\mu}{\sqrt{n\sigma^2}} $$
#     tiende a la función de distribución normal estándar cuando $n$ tiende a infinito.
#     <div style="text-align: right; margin-top: 10px; font-size: 0.9em; color: #6B21A8;">
#         <i>(Rincón, 2014, p. 376)</i>
#     </div>
# </div>

# %% [markdown]
# <h3>&#128187; <font color="#004D40"> Simulación en Python</font>  </3>

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# 1. Semilla para reproducibilidad
np.random.seed(123)

# 2. Parámetros de la población (Exponencial asimétrica con lambda=1.0)
lambda_param = 1.0
mu = 1.0 / lambda_param  # Media poblacional = 1.0
sigma = 1.0 / lambda_param  # Desviación estándar poblacional = 1.0

# 3. Parámetros de simulación Monte Carlo
n_simulaciones = 10000  # Número de muestras extraídas (M)
tamanos_muestra = [1, 2, 5, 30]  # TAMAÑOS DE MUESTRA n

# 4. Crear figura con 4 subgráficas (2x2)
fig, axes = plt.subplots(2, 2, figsize=(10, 7), dpi=120)
axes = axes.flatten()

# 5. Simular y graficar para cada tamaño de muestra n
for idx, n in enumerate(tamanos_muestra):
    ax = axes[idx]

    # Generar M muestras independientes de tamaño n y calcular la media de cada muestra
    muestras = np.random.exponential(scale=sigma, size=(n_simulaciones, n))
    medias_muestrales = np.mean(muestras, axis=1)

    # Histograma empírico de las medias muestrales (Azul UNAM)
    ax.hist(
        medias_muestrales,
        bins=45,
        density=True,
        color="#0F4C81",
        alpha=0.70,
        edgecolor="#082947",
        linewidth=0.7,
        label="Medias Muestrales",
        zorder=2,
    )

    # Error estándar teórico (Desviación estándar de la media)
    se = sigma / np.sqrt(n)

    # Curva de Densidad Normal Teórica N(mu, sigma / sqrt(n)) (Rojo Cárdeno)
    x_vals = np.linspace(
        np.min(medias_muestrales), np.max(medias_muestrales), 300
    )
    pdf_normal = norm.pdf(x_vals, loc=mu, scale=se)

    ax.plot(
        x_vals,
        pdf_normal,
        color="#E63946",
        linewidth=2.2,
        label=rf"$\mathcal{{N}}(\mu, \sigma/\sqrt{{{n}}})$",
        zorder=3,
    )

    # Formato visual por cuadrante
    ax.set_title(
        f"Tamaño de Muestra: n = {n}",
        fontsize=10.5,
        fontweight="bold",
        loc="left",
        pad=8,
    )
    ax.set_xlabel(
        r"Promedio Muestral ($\bar{X}_n$)", fontsize=8.5, fontweight="bold"
    )
    ax.set_ylabel("Densidad", fontsize=8.5, fontweight="bold")

    # Grilla y bordes
    ax.set_facecolor("white")
    ax.grid(True, color="#E2E8F0", linestyle="-", linewidth=0.7, zorder=0)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.spines["left"].set_color("#CBD5E1")
    ax.spines["bottom"].set_color("#CBD5E1")

    # Leyenda
    ax.legend(
        loc="upper right",
        frameon=True,
        facecolor="white",
        edgecolor="#CBD5E1",
        fontsize=8,
    )

# Título general y diseño
fig.suptitle(
    "Teorema del Límite Central: Convergencia a la Distribución Normal",
    fontsize=12,
    fontweight="bold",
    y=0.98,
)
fig.patch.set_facecolor("white")

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# ## <a id="18"></a><font color="#2F855A">7. Conclusiones</font>

# %% [markdown]
# En este Notebook se desarrollaron diferentes distribuciones que reflejan fenómenos diferentes.
#
# Cada distribución es la manera de describir de un fenómeno distinto: desde responder un simple "sí o no" en una encuesta, hasta medir cuánto tiempo haces fila. Además, todas tienen sus momentos (la media y la varianza) que te resumen dónde está el centro y qué tan dispersos están los datos sin tener que revisar dato por dato. Ahí es donde la Función Generadora de Momentos y la Función Característica cobran todo el sentido ya que guarda las características esenciales de la distribución y ayudan en el calculo de sus propiedades.
#
# Las simulaciones en Python comparando la teoría con la práctica muestran lo acertados que son los modelos teóricos para describir fenómenos que cuenten con características como las de cada distribución.
#
# Por último, la Ley de los Grandes Números y el Teorema Central del Límite son la muestra del valor que tiene hacer más observaciones en estadística.
#
# Con la Ley de los Grandes Números, sabemos que mientras más grande sea tu muestra, el promedio se va a acercar más a la realidad de la población (por eso importan tanto las muestras representativas). Y con el Teorema Central del Límite sabemos que no importa qué tan rara o asimétrica sea la distribución original de un fenómeno, si juntas suficientes observaciones, el promedio va a terminar dibujando una curva normal. Por eso usamos la normal como el estándar para entender datos en ciencias sociales.

# %% [markdown]
# <h2>&#128218; <a id="13"></a><font color="#2F855A">Referencias</font></h2>

# %% [markdown]
# <span style="color: #2B6CB0;">■</span> Rincón, L. (2014). <i>Introducción a la probabilidad</i> (1.a ed.) Universidad Nacional Autónoma de México, Facultad de Ciencias.
#
# <span style="color: #2B6CB0;">■</span> Wackerly, D., Mendenhall, W y Scheaffer, R. (2010). <i>Estadística matemática con aplicaciones</i> (7.a ed.) Cengage Learning Editores.
